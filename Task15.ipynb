# %% [markdown]
# https://python-graph-gallery.com/170-basic-venn-diagram-with-2-groups/

# %%
from matplotlib import pyplot as plt
from matplotlib_venn import venn2, venn3

set1 = ['a', 'b', 'c']
set2 = ['b','c','d','e']
diagram = venn2 ([set (set1), set (set2)])
plt.draw ()
